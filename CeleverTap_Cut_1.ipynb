# %%
 #inialization set up
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_video_details=pd.read_csv('VideoDetails.csv')

# %%
df_video_details.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3695451 entries, 0 to 3695450
# Data columns (total 12 columns):
# UserId           object
# Date             int64
# Minute_Of_Day    int64
# Second           int64
# State            int64
# Genre            object
# Category         object
# ProgramType      object
# Country          int64
# Device           int64
# OS               int64
# VideoId          object
# dtypes: int64(7), object(5)
# memory usage: 338.3+ MB

# %%
df_video_started=pd.read_csv('VideoStarted.csv',nrows=100)

# %%
df_video_started
# Out:
#                               UserId      Date  Minute_Of_Day  Second  State  \
# 0   0280dfdd112732a3ac12b12dc770b7af  20170106              0       8     35
# 1   435d41ae019cb8db785483793859c9a8  20170106              0      28     35
# 2   1faf0ce0b98e02e1568702f516f01a78  20170106              0      36     35
# 3   3ec691b9d2b5d53ef965fe59b1900b30  20170106              0      48     35
# 4   ff230d487a7139b65f33b54a4cbd2d9e  20170106              0      56     35
# 5   13d9f55e297d7d9c219fbe9085e1006c  20170106              1      24     35
# 6   ca601ff304bf0c0836f8a59f7751b8de  20170106              1      40     35
# 7   f717dc3f757dc18cc0c3f27ed3e94ef8  20170106              1      40     35
# 8   f717dc3f757dc18cc0c3f27ed3e94ef8  20170106              1      40     35
# 9   0d2717ba754737c78430788ed77a1db7  20170106              1      44     35
# 10  087c741c167a352d07822fcab58046e5  20170106              1      48     35
# ...

# %%
df_video_started['Date'] = df_video_started['Date'].apply(str)

# %%
df_video_started['Date']=pd.to_datetime(df_video_started['Date'], format='%Y%m%d', errors='ignore')

# %%
df_video_started['Timestamp']=pd.to_datetime(df_video_started.Date) + pd.to_timedelta(df_video_started.Minute_Of_Day, unit='m') + pd.to_timedelta(df_video_started.Second, unit='s')

# %%
df_video_started.head()
# Out:
#                              UserId       Date  Minute_Of_Day  Second  State  \
# 0  0280dfdd112732a3ac12b12dc770b7af 2017-01-06              0       8     35
# 1  435d41ae019cb8db785483793859c9a8 2017-01-06              0      28     35
# 2  1faf0ce0b98e02e1568702f516f01a78 2017-01-06              0      36     35
# 3  3ec691b9d2b5d53ef965fe59b1900b30 2017-01-06              0      48     35
# 4  ff230d487a7139b65f33b54a4cbd2d9e 2017-01-06              0      56     35
#
#        Genre Category ProgramType  Country  Device  OS  \
# 0   Romance      vod       Movies        1       1   2
# 1     Anime      vod     TV Shows        1       1   1
# 2     Drama      vod     TV Shows        1       1   1
# 3     Drama      vod     TV Shows        1       2   2
# 4    Comedy      vod       Movies        1       1   1
#
#                             VideoId           Timestamp
# 0  36a27b379622f342ec87f9aafadb8f94 2017-01-06 00:00:08
# 1  a4d9b88c7ed63d723c70b358a857719c 2017-01-06 00:00:28
# ...

# %%
df_app_lun=pd.read_csv('AppLaunched.csv')

# %%
df_app_lun.head()
# Out:
#                              UserId      Date  Minute_Of_Day  Second  State  \
# 0  a27134c322d4f56dabc106a6847cb96b  20170106              0       4     50
# 1  aab39ad0874c59cc388525d511667f9d  20170106              0       8     40
# 2  f717dc3f757dc18cc0c3f27ed3e94ef8  20170106              0      12     35
# 3  04c1e14fd54a06c0d4fe98cf0cb8b04c  20170106              0      20     40
# 4  71f05822bb699a04b694dd30265fdf73  20170106              0      20     35
#
#    Country  Device  OS
# 0        1       1   2
# 1        1       1   2
# 2        1       1   2
# 3        1       2   2
# 4        1       1   2

# %%
df_app_lun['Date'] = df_app_lun['Date'].apply(str)
df_app_lun['Date']=pd.to_datetime(df_app_lun['Date'], format='%Y%m%d', errors='ignore')
df_app_lun['Timestamp']=pd.to_datetime(df_app_lun.Date) + pd.to_timedelta(df_app_lun.Minute_Of_Day, unit='m') + pd.to_timedelta(df_app_lun.Second, unit='s')

# %%
merge1=pd.merge(df_video_started,df_app_lun,how='left',on='UserId')

# %%
merge1.head()
# Out:
#                              UserId     Date_x  Minute_Of_Day_x  Second_x  \
# 0  0280dfdd112732a3ac12b12dc770b7af 2017-01-06                0         8
# 1  435d41ae019cb8db785483793859c9a8 2017-01-06                0        28
# 2  1faf0ce0b98e02e1568702f516f01a78 2017-01-06                0        36
# 3  1faf0ce0b98e02e1568702f516f01a78 2017-01-06                0        36
# 4  1faf0ce0b98e02e1568702f516f01a78 2017-01-06                0        36
#
#    State_x      Genre Category ProgramType  Country_x  Device_x  \
# 0       35   Romance      vod       Movies          1         1
# 1       35     Anime      vod     TV Shows          1         1
# 2       35     Drama      vod     TV Shows          1         1
# 3       35     Drama      vod     TV Shows          1         1
# 4       35     Drama      vod     TV Shows          1         1
#
#           ...                                   VideoId         Timestamp_x  \
# ...

# %%
merge1[merge1['UserId']=='1faf0ce0b98e02e1568702f516f01a78']
# Out:
#                               UserId     Date_x  Minute_Of_Day_x  Second_x  \
# 2   1faf0ce0b98e02e1568702f516f01a78 2017-01-06                0        36
# 3   1faf0ce0b98e02e1568702f516f01a78 2017-01-06                0        36
# 4   1faf0ce0b98e02e1568702f516f01a78 2017-01-06                0        36
# 5   1faf0ce0b98e02e1568702f516f01a78 2017-01-06                0        36
# 6   1faf0ce0b98e02e1568702f516f01a78 2017-01-06                0        36
# 7   1faf0ce0b98e02e1568702f516f01a78 2017-01-06                0        36
# 8   1faf0ce0b98e02e1568702f516f01a78 2017-01-06                0        36
# 9   1faf0ce0b98e02e1568702f516f01a78 2017-01-06                0        36
# 10  1faf0ce0b98e02e1568702f516f01a78 2017-01-06                0        36
# 11  1faf0ce0b98e02e1568702f516f01a78 2017-01-06                0        36
# 12  1faf0ce0b98e02e1568702f516f01a78 2017-01-06                0        36
# ...

# %%
df_app_reg=pd.read_csv('Registration.csv')

# %%
df_app_reg['Date'] = df_app_reg['Date'].apply(str)
df_app_reg['Date']=pd.to_datetime(df_app_reg['Date'], format='%Y%m%d', errors='ignore')
df_app_reg['Timestamp']=pd.to_datetime(df_app_reg.Date) + pd.to_timedelta(df_app_reg.Minute_Of_Day, unit='m') + pd.to_timedelta(df_app_reg.Second, unit='s')

# %%
merge2=pd.merge(merge1,df_app_reg,how='left',on='UserId')

# %%
merge2
# Out:
#                                 UserId     Date_x  Minute_Of_Day_x  Second_x  \
# 0     0280dfdd112732a3ac12b12dc770b7af 2017-01-06                0         8
# 1     435d41ae019cb8db785483793859c9a8 2017-01-06                0        28
# 2     1faf0ce0b98e02e1568702f516f01a78 2017-01-06                0        36
# 3     1faf0ce0b98e02e1568702f516f01a78 2017-01-06                0        36
# 4     1faf0ce0b98e02e1568702f516f01a78 2017-01-06                0        36
# 5     1faf0ce0b98e02e1568702f516f01a78 2017-01-06                0        36
# 6     1faf0ce0b98e02e1568702f516f01a78 2017-01-06                0        36
# 7     1faf0ce0b98e02e1568702f516f01a78 2017-01-06                0        36
# 8     1faf0ce0b98e02e1568702f516f01a78 2017-01-06                0        36
# 9     1faf0ce0b98e02e1568702f516f01a78 2017-01-06                0        36
# 10    1faf0ce0b98e02e1568702f516f01a78 2017-01-06                0        36
# ...

# %%
df_video_details
# Out:
#                                    UserId      Date  Minute_Of_Day  Second  \
# 0        dc93d200565e5bf6e6fc55adb1c5ba06  20170106              0       4
# 1        12060efd8b68ea562b265d0129a8af1f  20170106              0      16
# 2        9151ab2a901458f27e36548d4a8dc011  20170106              0      20
# 3        1faf0ce0b98e02e1568702f516f01a78  20170106              0      20
# 4        435d41ae019cb8db785483793859c9a8  20170106              0      20
# 5        434200a07e2d14835580cee9ddcf978c  20170106              0      24
# 6        1faf0ce0b98e02e1568702f516f01a78  20170106              0      28
# 7        3ec691b9d2b5d53ef965fe59b1900b30  20170106              0      40
# 8        9151ab2a901458f27e36548d4a8dc011  20170106              0      44
# 9        cc3c6d5497235af3c445f41296a4e81f  20170106              0      44
# 10       789aa3970808b9c006306f08db926b41  20170106              0      44
# ...

# %%
df_video_details['Date'] = df_video_details['Date'].apply(str)
df_video_details['Date']=pd.to_datetime(df_video_details['Date'], format='%Y%m%d', errors='ignore')
df_video_details['Timestamp']=pd.to_datetime(df_video_details.Date) + pd.to_timedelta(df_video_details.Minute_Of_Day, unit='m') + pd.to_timedelta(df_video_details.Second, unit='s')

# %%
merge3=pd.merge(merge2,df_video_details,how='left',on='UserId')

# %%
merge3.to_csv('final_file_2.csv',index=False)

# %%
df_utm_vist=pd.read_csv('UTMVisited.csv')

# %%
df_utm_vist['Date'] = df_utm_vist['Date'].apply(str)
df_utm_vist['Date']=pd.to_datetime(df_utm_vist['Date'], format='%Y%m%d', errors='ignore')
df_utm_vist['Timestamp']=pd.to_datetime(df_utm_vist.Date) + pd.to_timedelta(df_utm_vist.Minute_Of_Day, unit='m') + pd.to_timedelta(df_utm_vist.Second, unit='s')

# %%
merge4=pd.merge(merge3,df_utm_vist,how='left',on='UserId')

# %%
import dill
dill.dump_session('notebook_env.db')
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-39-edf038076cd6> in <module>()
#       1 import dill
# ----> 2 dill.dump_session('notebook_env.db')
#
# ~\Anaconda3\lib\site-packages\dill\_dill.py in dump_session(filename, main, byref)
#     391         pickler._recurse = False # disable pickling recursion for globals
#     392         pickler._session = True  # is best indicator of when pickling a session
# --> 393         pickler.dump(main)
#     394     finally:
#     395         if f is not filename:  # If newly opened file
#
# ~\Anaconda3\lib\pickle.py in dump(self, obj)
#     407         if self.proto >= 4:
#     408             self.framer.start_framing()
# --> 409         self.save(obj)
#     410         self.write(STOP)
#     411         self.framer.end_framing()
#
# ~\Anaconda3\lib\pickle.py in save(self, obj, save_persistent_id)
# ...

# %%
............................./
